# %%
import pandas as pd
import json

ruta_archivo_json = 'C:\\Users\\ROXI\\OneDrive\\Escritorio\\henry\\pi\\PI01_DATA03\\Datasets\\results.json'
with open("./Datasets/drivers.json") as archivo:salida = [json.loads(linea) for linea in archivo] drivers = pd.json_normalize(salida, sep="_")
datos = pd.read_json(ruta_archivo_json, lines=True)
#datos.info()
datos1=datos[datos["driverId"]==1]
datos1

#24959
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 26           27      19         1              1     22     9        5
# 56           57      20         1              1     22     3       13
# 68           69      21         1              1     22     5        3
# 89           90      22         1              1     22     3        2
# ...         ...     ...       ...            ...    ...   ...      ...
# 24840     24846    1042         1            131     44     1        1
# 24860     24866    1043         1            131     44     2        1
# 24880     24886    1044         1            131     44     6        1
# 24900     24906    1045         1            131     44     1        1
# 24942     24948    1047         1            131     44     3        3
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
datos
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 24955     24961    1047       841             51     99    14       16
# 24956     24962    1047       849              3      6    18       17
# 24957     24963    1047       825            210     20    20       18
# 24958     24964    1047       850            210     51    17       19
# 24959     24965    1047       815            211     11    19       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
results[["driverId","points"]].groupby("driverId").sum()
