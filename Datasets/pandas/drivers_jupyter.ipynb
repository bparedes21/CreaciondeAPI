# %%
import pandas as pd

ruta_archivo_json = 'C:\\Users\\ROXI\\OneDrive\\Escritorio\\henry\\pi\\PI01_DATA03\\Datasets\\drivers.json'
datos = pd.read_json(ruta_archivo_json,  lines=True, encoding="utf-8")
datos
# Out:
#      driverId          driverRef number code  \
# 0           1           hamilton     44  HAM
# 1           2           heidfeld     \N  HEI
# 2           3            rosberg      6  ROS
# 3           4             alonso     14  ALO
# 4           5         kovalainen     \N  KOV
# ..        ...                ...    ...  ...
# 848       850  pietro_fittipaldi     51  FIT
# 849       851             aitken     89  AIT
# 850       852            tsunoda     \N  TSU
# 851       853            mazepin     \N  MAZ
# 852       854    mick_schumacher     \N  SCH
#
#                                                 name         dob nationality  \
# 0       {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1        {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
# 2         {'forename': 'Nico', 'surname': 'Rosberg'}  1985-06-27      German
# 3      {'forename': 'Fernando', 'surname': 'Alonso'}  1981-07-29     Spanish
# ...

# %%
datos_dict=datos['name'].to_dict()

# %%
datos[["forename","surname"]]=pd.DataFrame.from_dict(datos_dict,orient='index')

# %%
datos.to_csv('drivers_.csv', encoding='utf-8', index=False)

# %%
datos_df1=pd.read_csv(r'C:\Users\ROXI\OneDrive\Escritorio\Proyecto Individual 1- Data 03- Soy Henry\Proyecto-Individual-1\Datasets\pandas\dataset_procesados\drivers_.csv')

# %%
datos.drop(columns="name")
# Out:
#      driverId          driverRef number code         dob nationality  \
# 0           1           hamilton     44  HAM  1985-01-07     British
# 1           2           heidfeld     \N  HEI  1977-05-10      German
# 2           3            rosberg      6  ROS  1985-06-27      German
# 3           4             alonso     14  ALO  1981-07-29     Spanish
# 4           5         kovalainen     \N  KOV  1981-10-19     Finnish
# ..        ...                ...    ...  ...         ...         ...
# 848       850  pietro_fittipaldi     51  FIT  1996-06-25   Brazilian
# 849       851             aitken     89  AIT  1995-09-23     British
# 850       852            tsunoda     \N  TSU  2000-05-11    Japanese
# 851       853            mazepin     \N  MAZ  1999-03-02     Russian
# 852       854    mick_schumacher     \N  SCH  1999-03-22      German
#
#                                                 url  forename     surname
# ...

# %%
datos=datos.drop(columns="name")

# %%
datos
# Out:
#      driverId          driverRef number code         dob nationality  \
# 0           1           hamilton     44  HAM  1985-01-07     British
# 1           2           heidfeld     \N  HEI  1977-05-10      German
# 2           3            rosberg      6  ROS  1985-06-27      German
# 3           4             alonso     14  ALO  1981-07-29     Spanish
# 4           5         kovalainen     \N  KOV  1981-10-19     Finnish
# ..        ...                ...    ...  ...         ...         ...
# 848       850  pietro_fittipaldi     51  FIT  1996-06-25   Brazilian
# 849       851             aitken     89  AIT  1995-09-23     British
# 850       852            tsunoda     \N  TSU  2000-05-11    Japanese
# 851       853            mazepin     \N  MAZ  1999-03-02     Russian
# 852       854    mick_schumacher     \N  SCH  1999-03-22      German
#
#                                                 url  forename     surname
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 853 entries, 0 to 852
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     853 non-null    int64
#  1   driverRef    853 non-null    object
#  2   number       853 non-null    object
#  3   code         853 non-null    object
#  4   dob          853 non-null    object
#  5   nationality  853 non-null    object
#  6   url          853 non-null    object
#  7   forename     853 non-null    object
#  8   surname      853 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 60.1+ KB

# %%
datos[datos['driverId'] == 18]
# Out:
#     driverId driverRef number code  \
# 17        18    button     22  BUT
#
#                                            name         dob nationality  \
# 17  {'forename': 'Jenson', 'surname': 'Button'}  1980-01-19     British
#
#                                            url
# 17  http://en.wikipedia.org/wiki/Jenson_Button

# %%
#convert to lower case
datos['driverRef'] = datos['driverRef'].str.lower()
# remove trailing white spaces
datos['driverRef'] = datos['driverRef'].str.strip()

# %%
sort_values=datos['driverRef'].sort_values()
sort_values.unique()
# Out:
# array(['abate', 'abecassis', 'acheson', 'adamich', 'adams', 'ader',
#        'adolff', 'agabashian', 'ahrens', 'aitken', 'alan_brown', 'albers',
#        'albon', 'alboreto', 'alesi', 'alguersuari', 'alliot', 'allison',
#        'alonso', 'amati', 'ambrosio', 'amick', 'amon', 'anderson',
#        'andersson', 'andre_pilette', 'andretti', 'andrews', 'angelis',
#        'apicella', 'armi', 'arnold', 'arnoux', 'arundell', 'ascari',
#        'ashdown', 'ashley', 'ashmore', 'aston', 'attwood', 'ayulo',
#        'badoer', 'baghetti', 'bailey', 'baldi', 'ball', 'balsa',
#        'bandini', 'banks', 'barbazza', 'barber', 'barilla', 'barrichello',
#        'bartels', 'barth', 'bassi', 'bauer', 'baumgartner', 'bayol',
#        'beaufort', 'beauman', 'bechem', 'behra', 'bell', 'bellof',
#        'belmondo', 'belso', 'beltoise', 'beretta', 'berg', 'berger',
#        'bernard', 'bernoldi', 'bertaggia', 'bettenhausen', 'beuttler',
# ...

# %%
#convert to lower case
datos['code'] = datos['code'].str.lower()
# remove trailing white spaces
datos['code'] = datos['code'].str.strip()

# %%
sort_code=datos['code'].sort_values()
sort_code.unique()
# Out:
# array(['\\n', 'ait', 'alb', 'alg', 'alo', 'bad', 'bar', 'bia', 'bot',
#        'bou', 'bue', 'but', 'cha', 'chi', 'cou', 'dam', 'dav', 'dig',
#        'dir', 'dlr', 'doo', 'eri', 'fis', 'fit', 'fmo', 'fri', 'gas',
#        'gio', 'glo', 'gro', 'gut', 'ham', 'har', 'hei', 'hul', 'ide',
#        'kar', 'kli', 'kob', 'kov', 'kub', 'kvy', 'lat', 'lec', 'liu',
#        'lot', 'mag', 'mal', 'mas', 'maz', 'mer', 'mon', 'msc', 'nak',
#        'nas', 'nor', 'oco', 'pal', 'per', 'pet', 'pic', 'piq', 'piz',
#        'rai', 'ric', 'ros', 'rss', 'rus', 'sai', 'sat', 'sch', 'sen',
#        'sir', 'spe', 'ste', 'str', 'sut', 'tmo', 'tru', 'tsu', 'van',
#        'vdg', 'ver', 'vet', 'vil', 'web', 'weh', 'win', 'wur', 'yam',
#        'zon'], dtype=object)

# %%
#convert to lower case
datos['nationality'] = datos['nationality'].str.lower()
# remove trailing white spaces
datos['nationality'] = datos['nationality'].str.strip()

# %%
sort_nationality=datos['nationality'].sort_values()
sort_nationality.unique()
# Out:
# array(['american', 'american-italian', 'argentine', 'argentine-italian',
#        'australian', 'austrian', 'belgian', 'brazilian', 'british',
#        'canadian', 'chilean', 'colombian', 'czech', 'danish', 'dutch',
#        'east german', 'finnish', 'french', 'german', 'hungarian',
#        'indian', 'indonesian', 'irish', 'italian', 'japanese',
#        'liechtensteiner', 'malaysian', 'mexican', 'monegasque',
#        'new zealander', 'polish', 'portuguese', 'rhodesian', 'russian',
#        'south african', 'spanish', 'swedish', 'swiss', 'thai',
#        'uruguayan', 'venezuelan'], dtype=object)

# %%
#convert to lower case
datos['forename'] = datos['forename'].str.lower()
# remove trailing white spaces
datos['forename'] = datos['forename'].str.strip()

# %%
sort_forename=datos['forename'].sort_values(ascending=False)
sort_forename.unique()
# Out:
# array(['óscar', 'érik', 'éric', 'élie', 'zsolt', 'yves', 'yuki', 'yuji',
#        'yannick', 'wolfgang', 'wilson', 'willy', 'willi', 'will', 'wayne',
#        'warwick', 'walt', 'volker', 'vittorio', 'vitantonio', 'vitaly',
#        'vincenzo', 'vic', 'vern', 'valtteri', 'umberto', 'ukyo', 'troy',
#        'trevor', 'travis', 'toulo', 'toshio', 'torsten', 'toranosuke',
#        'tony', 'toni', 'tomáš', 'tommy', 'tom', 'timo', 'timmy', 'tim',
#        'tiff', 'tiago', 'thomas', 'thierry', 'theo', 'teo', 'teddy',
#        'ted', 'tarso', 'takuma', 'taki', 'sébastien', 'syd', 'stéphane',
#        'stuart', 'stoffel', 'stirling', 'stephen', 'stefano', 'stefan',
#        'slim', 'skip', 'silvio', 'siegfried', 'shorty', 'shinji',
#        'sergio', 'sergey', 'sebastian', 'scott', 'satoru', 'sam', 'sakon',
#        'rupert', 'rudolf', 'rudi', 'rubens', 'roy', 'ronnie', 'ron',
#        'romain', 'rolf', 'roland', 'roger', 'roelof', 'rodney', 'rodger',
# ...

# %%
rep = {'ã':'a','á':'a','é':'e','í':'i','ó':'o','ô':'o','ú':'u','`a':'a','è':'e','ì':'i','ò':'o','ù':'u','ç':'c','ñ':'n','š':'s','ø':''}

datos['forename'] =datos['forename'].replace(rep, regex=True)

# %%
import unicodedata 
def remove_accents(input_str):
    nkfd_form = unicodedata.normalize('NFKD', input_str) 
    only_ascii = nkfd_form.encode('ASCII', 'ignore') 
    only_ascii
    
    return only_ascii

# %%
# Apply to your df
datos_decode= datos["forename"].apply(remove_accents)

# %%
datos["forename"]=datos_decode.str.decode('utf8', errors='strict')

# %%
#convert to lower case
datos['surname'] = datos['surname'].str.lower()
# remove trailing white spaces
datos['surname'] = datos['surname'].str.strip()

# %%
sort_forename=datos['surname'].sort_values()
sort_forename.unique()
# Out:
# array(['abate', 'abecassis', 'acheson', 'adams', 'ader', 'adolff',
#        'agabashian', 'ahrens', 'aitken', 'albers', 'albon', 'alboreto',
#        'alesi', 'alguersuari', 'alliot', 'allison', 'alonso', 'amati',
#        'amick', 'amon', 'anderson', 'andersson', 'andretti', 'andrews',
#        'apicella', 'armi', 'arnold', 'arnoux', 'arundell', 'ascari',
#        'ashdown', 'ashley', 'ashmore', 'aston', 'attwood', 'ayulo',
#        'badoer', 'baghetti', 'bailey', 'baldi', 'ball', 'balsa',
#        'bandini', 'banks', 'barbazza', 'barber', 'barilla', 'barrichello',
#        'bartels', 'barth', 'bassi', 'bauer', 'baumgartner', 'bayol',
#        'beauman', 'bechem', 'behra', 'bell', 'bellof', 'belmondo',
#        'belsø', 'beltoise', 'beretta', 'berg', 'berger', 'bernard',
#        'bernoldi', 'bertaggia', 'bettenhausen', 'beuttler', 'bianchi',
#        'bianco', 'binder', 'biondetti', 'bira', 'birger', 'bisch',
#        'blanchard', 'bleekemolen', 'blignaut', 'blokdyk', 'blundell',
# ...

# %%
rep = {'ã':'a','á':'a','é':'e','í':'i','ó':'o','ô':'o','ú':'u','`a':'a','è':'e','ì':'i','ò':'o','ù':'u','ç':'c','ñ':'n','š':'s','Ø':'','ø':'',}

datos['surname'] =datos['surname'].replace(rep, regex=True)

# %%
datos_decode= datos["surname"].apply(remove_accents)

# %%
datos["surname"]=datos_decode.str.decode('utf8', errors='strict')

# %%
datos["surname"]=datos["surname"].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# %%
datos.head()
# Out:
#    driverId   driverRef number code         dob nationality  \
# 0         1    hamilton     44  ham  1985-01-07     british
# 1         2    heidfeld     \N  hei  1977-05-10      german
# 2         3     rosberg      6  ros  1985-06-27      german
# 3         4      alonso     14  alo  1981-07-29     spanish
# 4         5  kovalainen     \N  kov  1981-10-19     finnish
#
#                                               url  forename     surname
# 0     http://en.wikipedia.org/wiki/Lewis_Hamilton     lewis    hamilton
# 1      http://en.wikipedia.org/wiki/Nick_Heidfeld      nick    heidfeld
# 2       http://en.wikipedia.org/wiki/Nico_Rosberg      nico     rosberg
# 3    http://en.wikipedia.org/wiki/Fernando_Alonso  fernando      alonso
# 4  http://en.wikipedia.org/wiki/Heikki_Kovalainen    heikki  kovalainen

# %%
datos.to_csv('drivers_.csv', encoding='utf-8', index=False)

# %%
datos_df=pd.read_csv(r'C:\Users\ROXI\OneDrive\Escritorio\Proyecto Individual 1- Data 03- Soy Henry\Proyecto-Individual-1\Datasets\pandas\dataset_procesados\drivers_.csv',encoding='utf-8-sig')

# %%
#convert to lower case
datos['url'] = datos['url'].str.lower()
# remove trailing white spaces
datos['url'] = datos['url'].str.strip()

# %%
sort_forename=datos_df['number'].sort_values()
sort_forename.unique()
# Out:
# array(['10', '11', '12', '13', '14', '16', '17', '18', '19', '2', '20',
#        '21', '22', '23', '25', '26', '27', '28', '3', '30', '31', '33',
#        '35', '4', '44', '45', '5', '51', '53', '55', '6', '63', '7', '77',
#        '8', '88', '89', '9', '94', '98', '99', '\\N'], dtype=object)

# %%
import numpy as np

# %%
datos_df['number']=datos_df['number'].replace('\\N',np.nan)

# %%
datos_df.to_csv('drivers_.csv', encoding='utf-8', index=False)

# %%
datos_df=pd.read_csv(r'C:\Users\ROXI\OneDrive\Escritorio\Proyecto Individual 1- Data 03- Soy Henry\Proyecto-Individual-1\Datasets\pandas\dataset_procesados\drivers_.csv',encoding='utf-8-sig')

# %%
datos_df
# Out:
#      driverId          driverRef  number code         dob nationality  \
# 0           1           hamilton    44.0  ham  1985-01-07     british
# 1           2           heidfeld     NaN  hei  1977-05-10      german
# 2           3            rosberg     6.0  ros  1985-06-27      german
# 3           4             alonso    14.0  alo  1981-07-29     spanish
# 4           5         kovalainen     NaN  kov  1981-10-19     finnish
# ..        ...                ...     ...  ...         ...         ...
# 848       850  pietro_fittipaldi    51.0  fit  1996-06-25   brazilian
# 849       851             aitken    89.0  ait  1995-09-23     british
# 850       852            tsunoda     NaN  tsu  2000-05-11    japanese
# 851       853            mazepin     NaN  maz  1999-03-02     russian
# 852       854    mick_schumacher     NaN  sch  1999-03-22      german
#
#                                                 url  forename     surname
# ...

# %% [markdown]
# american, british

# %%
pilotos=datos_df[(datos_df['nationality'] == "american") | (datos_df['nationality'] == "british")]

# %%
conductor_american_british=pilotos["driverId"].values

# %%
conductor_american_british
# Out:
# array([  1,  14,  18,  19,  26,  51,  56,  65,  66,  71,  84,  87,  95,
#        118, 121, 135, 141, 151, 156, 158, 174, 186, 187, 193, 205, 207,
#        209, 211, 214, 226, 227, 231, 239, 240, 242, 245, 249, 252, 259,
#        262, 264, 265, 270, 276, 282, 283, 288, 289, 294, 301, 302, 305,
#        308, 309, 312, 320, 321, 322, 328, 329, 332, 335, 341, 342, 344,
#        350, 353, 354, 357, 361, 364, 366, 367, 370, 373, 374, 378, 381,
#        383, 386, 387, 388, 390, 391, 392, 393, 395, 396, 397, 398, 399,
#        400, 401, 403, 404, 405, 407, 418, 419, 420, 421, 422, 433, 434,
#        436, 437, 438, 440, 441, 449, 451, 452, 453, 456, 459, 460, 462,
#        463, 465, 468, 469, 470, 475, 477, 479, 481, 484, 486, 490, 494,
#        495, 501, 502, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514,
#        515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527,
#        528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540,
# ...

# %% [markdown]
# - Piloto con mayor cantidad de puntos en total, cuyo constructor sea de nacionalidad sea American o British
